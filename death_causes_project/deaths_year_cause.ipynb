# %% [markdown]
# # Deaths by State, Year, and Cause

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading CSV file
#
# Read csv file with pandas and made into a DataFrame.

# %%
csv_file = pd.read_csv("Weekly_Counts_of_Death_by_Jurisdiction_and_Select_Causes_of_Death_new_file.csv", low_memory=False)

deaths_cause_df = pd.DataFrame(csv_file)
deaths_cause_df.head(50)
# Out:
#    Jurisdiction Week Ending Date State Abbreviation  Year  Week  \
# 0       Alabama        1/10/2015                 AL  2015     1
# 1       Alabama        1/10/2015                 AL  2015     1
# 2       Alabama         1/9/2016                 AL  2016     1
# 3       Alabama         1/9/2016                 AL  2016     1
# 4       Alabama         1/7/2017                 AL  2017     1
# 5       Alabama         1/7/2017                 AL  2017     1
# 6       Alabama         1/6/2018                 AL  2018     1
# 7       Alabama         1/6/2018                 AL  2018     1
# 8       Alabama         1/5/2019                 AL  2019     1
# 9       Alabama         1/5/2019                 AL  2019     1
# 10      Alabama         1/4/2020                 AL  2020     1
# 11      Alabama         1/4/2020                 AL  2020     1
# 12      Alabama         1/9/2021                 AL  2021     1
# 13      Alabama         1/9/2021                 AL  2021     1
# 14      Alabama         1/8/2022                 AL  2022     1
# 15      Alabama         1/8/2022                 AL  2022     1
# 16      Alabama        1/17/2015                 AL  2015     2
# 17      Alabama        1/17/2015                 AL  2015     2
# 18      Alabama        1/16/2016                 AL  2016     2
# 19      Alabama        1/16/2016                 AL  2016     2
# 20      Alabama        1/14/2017                 AL  2017     2
# 21      Alabama        1/14/2017                 AL  2017     2
# 22      Alabama        1/13/2018                 AL  2018     2
# 23      Alabama        1/13/2018                 AL  2018     2
# 24      Alabama        1/12/2019                 AL  2019     2
# 25      Alabama        1/12/2019                 AL  2019     2
# 26      Alabama        1/11/2020                 AL  2020     2
# 27      Alabama        1/11/2020                 AL  2020     2
# 28      Alabama        1/16/2021                 AL  2021     2
# 29      Alabama        1/16/2021                 AL  2021     2
# 30      Alabama        1/15/2022                 AL  2022     2
# 31      Alabama        1/15/2022                 AL  2022     2
# 32      Alabama        1/24/2015                 AL  2015     3
# 33      Alabama        1/24/2015                 AL  2015     3
# 34      Alabama        1/23/2016                 AL  2016     3
# 35      Alabama        1/23/2016                 AL  2016     3
# 36      Alabama        1/21/2017                 AL  2017     3
# 37      Alabama        1/21/2017                 AL  2017     3
# 38      Alabama        1/20/2018                 AL  2018     3
# 39      Alabama        1/20/2018                 AL  2018     3
# 40      Alabama        1/19/2019                 AL  2019     3
# 41      Alabama        1/19/2019                 AL  2019     3
# 42      Alabama        1/18/2020                 AL  2020     3
# 43      Alabama        1/18/2020                 AL  2020     3
# 44      Alabama        1/23/2021                 AL  2021     3
# 45      Alabama        1/23/2021                 AL  2021     3
# 46      Alabama        1/22/2022                 AL  2022     3
# 47      Alabama        1/22/2022                 AL  2022     3
# 48      Alabama        1/31/2015                 AL  2015     4
# 49      Alabama        1/31/2015                 AL  2015     4
#
# 14  Alzheimer disease and dementia        2022      NaN
# 15  Alzheimer disease and dementia        2022      NaN
# 16  Alzheimer disease and dementia   2015-2019      NaN
# 17  Alzheimer disease and dementia   2015-2019      NaN
# 18  Alzheimer disease and dementia   2015-2019      NaN
# 19  Alzheimer disease and dementia   2015-2019      NaN
# 20  Alzheimer disease and dementia   2015-2019      NaN
# 21  Alzheimer disease and dementia   2015-2019      NaN
# 22  Alzheimer disease and dementia   2015-2019      NaN
# 23  Alzheimer disease and dementia   2015-2019      NaN
# 24  Alzheimer disease and dementia   2015-2019      NaN
# 25  Alzheimer disease and dementia   2015-2019      NaN
# 26  Alzheimer disease and dementia        2020      NaN
# 27  Alzheimer disease and dementia        2020      NaN
# 28  Alzheimer disease and dementia        2021      NaN
# 29  Alzheimer disease and dementia        2021      NaN
# 30  Alzheimer disease and dementia        2022      NaN
# 31  Alzheimer disease and dementia        2022      NaN
# 32  Alzheimer disease and dementia   2015-2019      NaN
# 33  Alzheimer disease and dementia   2015-2019      NaN
# 34  Alzheimer disease and dementia   2015-2019      NaN
# 35  Alzheimer disease and dementia   2015-2019      NaN
# 36  Alzheimer disease and dementia   2015-2019      NaN
# 37  Alzheimer disease and dementia   2015-2019      NaN
# 38  Alzheimer disease and dementia   2015-2019      NaN
# 39  Alzheimer disease and dementia   2015-2019      NaN
# 40  Alzheimer disease and dementia   2015-2019      NaN
# 41  Alzheimer disease and dementia   2015-2019      NaN
# 42  Alzheimer disease and dementia        2020      NaN
# 43  Alzheimer disease and dementia        2020      NaN
# 44  Alzheimer disease and dementia        2021      NaN
# 45  Alzheimer disease and dementia        2021      NaN
# 46  Alzheimer disease and dementia        2022      NaN
# 47  Alzheimer disease and dementia        2022      NaN
# 48  Alzheimer disease and dementia   2015-2019      NaN
# 49  Alzheimer disease and dementia   2015-2019      NaN
#
#                                                  Note  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  Data in recent weeks are incomplete. Only 60% ...
# 13  Data in recent weeks are incomplete. Only 60% ...
# 14  Data in recent weeks are incomplete. Only 60% ...
# 15  Data in recent weeks are incomplete. Only 60% ...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  Data in recent weeks are incomplete. Only 60% ...
# 29  Data in recent weeks are incomplete. Only 60% ...
# 30  Data in recent weeks are incomplete. Only 60% ...
# 31  Data in recent weeks are incomplete. Only 60% ...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44  Data in recent weeks are incomplete. Only 60% ...
# 45  Data in recent weeks are incomplete. Only 60% ...
# 46  Data in recent weeks are incomplete. Only 60% ...
# 47  Data in recent weeks are incomplete. Only 60% ...
# 48                                                NaN
# 49                                                NaN
#
#     Average Number of Deaths in Time Period  \
# 0                                       103
# 1                                       103
# 2                                       103
# 3                                       103
# 4                                       103
# 5                                       103
# 6                                       103
# 7                                       103
# 8                                       103
# 9                                       103
# 10                                      102
# 11                                      102
# 12                                      122
# 13                                      122
# 14                                      100
# 15                                      100
# 16                                      102
# 17                                      102
# 18                                      102
# 19                                      102
# 20                                      102
# 21                                      102
# 22                                      102
# 23                                      102
# 24                                      102
# 25                                      102
# 26                                       96
# 27                                       96
# 28                                      114
# 29                                      114
# 30                                      137
# 31                                      137
# 32                                      110
# 33                                      110
# 34                                      110
# 35                                      110
# 36                                      110
# 37                                      110
# 38                                      110
# 39                                      110
# 40                                      110
# 41                                      110
# 42                                      106
# 43                                      106
# 44                                      120
# 45                                      120
# 46                                      126
# 47                                      126
# 48                                      107
# 49                                      107
#
#     Difference from 2015-2019 to 2020  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                               -1.0
# 11                                NaN
# 12                               19.0
# 13                                NaN
# 14                               -3.0
# 15                                NaN
# 16                                NaN
# 17                                NaN
# 18                                NaN
# 19                                NaN
# 20                                NaN
# 21                                NaN
# 22                                NaN
# 23                                NaN
# 24                                NaN
# 25                                NaN
# 26                               -6.0
# 27                                NaN
# 28                               12.0
# 29                                NaN
# 30                               35.0
# 31                                NaN
# 32                                NaN
# 33                                NaN
# 34                                NaN
# 35                                NaN
# 36                                NaN
# 37                                NaN
# 38                                NaN
# 39                                NaN
# 40                                NaN
# 41                                NaN
# 42                               -4.0
# 43                                NaN
# 44                               10.0
# 45                                NaN
# 46                               16.0
# 47                                NaN
# 48                                NaN
# 49                                NaN
#
#     Percent Difference from 2015-2019 to 2020                  Type
# 0                                         NaN  Predicted (weighted)
# 1                                         NaN            Unweighted
# 2                                         NaN  Predicted (weighted)
# 3                                         NaN            Unweighted
# 4                                         NaN  Predicted (weighted)
# 5                                         NaN            Unweighted
# 6                                         NaN  Predicted (weighted)
# 7                                         NaN            Unweighted
# 8                                         NaN  Predicted (weighted)
# 9                                         NaN            Unweighted
# 10                                       -1.0  Predicted (weighted)
# 11                                        NaN            Unweighted
# 12                                       18.4  Predicted (weighted)
# 13                                        NaN            Unweighted
# 14                                       -2.9  Predicted (weighted)
# 15                                        NaN            Unweighted
# 16                                        NaN  Predicted (weighted)
# 17                                        NaN            Unweighted
# 18                                        NaN  Predicted (weighted)
# 19                                        NaN            Unweighted
# 20                                        NaN  Predicted (weighted)
# 21                                        NaN            Unweighted
# 22                                        NaN  Predicted (weighted)
# 23                                        NaN            Unweighted
# 24                                        NaN  Predicted (weighted)
# 25                                        NaN            Unweighted
# 26                                       -5.9  Predicted (weighted)
# 27                                        NaN            Unweighted
# 28                                       11.8  Predicted (weighted)
# 29                                        NaN            Unweighted
# 30                                       34.3  Predicted (weighted)
# 31                                        NaN            Unweighted
# 32                                        NaN  Predicted (weighted)
# 33                                        NaN            Unweighted
# 34                                        NaN  Predicted (weighted)
# 35                                        NaN            Unweighted
# 36                                        NaN  Predicted (weighted)
# 37                                        NaN            Unweighted
# 38                                        NaN  Predicted (weighted)
# 39                                        NaN            Unweighted
# 40                                        NaN  Predicted (weighted)
# 41                                        NaN            Unweighted
# 42                                       -3.6  Predicted (weighted)
# 43                                        NaN            Unweighted
# 44                                        9.1  Predicted (weighted)
# 45                                        NaN            Unweighted
# 46                                       14.5  Predicted (weighted)
# 47                                        NaN            Unweighted
# 48                                        NaN  Predicted (weighted)
# 49                                        NaN            Unweighted

# %% [markdown]
# Because I won't be using these columns or they don't have enough data I will be dropping them.

# %%
deaths_cause_df.drop(deaths_cause_df.columns[[1, 8, 9, 10, 11, 12, 13 ]], inplace=True, axis=1)

# %%
description = [
["Jurisdiction","Jurisdiction of occurrence"],
["Week Ending Date","Week ending date"],
["State Abbreviation","State abbreviation"],
["Year","Year"],
["Week","Week number"],
["Cause Group","Cause group"],
["Number of Deaths", "Number of deaths"],
["Cause Subgroup", "Cause Subgroup"],
["Time Period","Time period"],
["Suppress","Flag for data suppression"],
["Note","Note about data"],
["Average Number of Deaths in Time Period","Average number of deaths in a given time period and week number"],
["Difference from 2015-2019 to 2020","Difference in the number of deaths in 2020 relative to 2015-2019"],
["Percent Difference from 2015-2019 to 2020","Percent difference in the number of deaths in 2020 relative to 2015-2019"],
["Type", "Estimate type (predicted or observed)"]]

column_desc = pd.DataFrame(description,columns=["column_name","description"])

# changeing index to column name
column_desc.set_index("column_name", inplace=True)

def find_desc(desc_name):
    for word in column_desc.index:
        if desc_name.lower() in word.lower():
            return column_desc.loc[word]

        
# finding the description of our columns with either uppercase or lowercase words.
find_desc("type")
# Out:
# description    Estimate type (predicted or observed)
# Name: Type, dtype: object

# %% [markdown]
# Removing duplicates and only getting the rows that were observed or unweighted because I wanted to get the real numbers.

# %%
# using unweighted deaths because they are the real deaths not predicted and that would be duplicate years.
death_cause_unweighted = deaths_cause_df[(deaths_cause_df["Type"] == "Unweighted") & (deaths_cause_df["Jurisdiction"] != "Puerto Rico") & (deaths_cause_df["Jurisdiction"] != "United States")]

# making dataset into a csv so I can look at in in tableau.
death_cause_unweighted.to_csv("deaths_and_cause_dataset.csv", index=False)

# Total deaths in the unweighted dataset
total_deaths = death_cause_unweighted["Number of Deaths"].sum()

len_years = len(death_cause_unweighted["Year"].unique())

# average number of deaths in our dataset
avg_deaths = f"{total_deaths/len_years:,}"
avg_deaths

deaths_each_year = death_cause_unweighted[["Year", "Number of Deaths"]].groupby("Year").sum()

# %%
# number of deaths that each cause group had
deaths_per_cause = death_cause_unweighted[["Cause Group", "Number of Deaths"]].groupby("Cause Group").sum("Number of Deaths")
deaths_per_cause.reset_index(inplace=True)

print(f"Max:{deaths_per_cause.max()}\n\nMin:{deaths_per_cause.min()}")
# Out:
# Max:Cause Group         Respiratory diseases
# Number of Deaths               6786035.0
# dtype: object
#
# Min:Cause Group         Alzheimer disease and dementia
# Number of Deaths                         1299921.0
# dtype: object

# %%
# number of total deaths in each state
num_deaths_by_state = death_cause_unweighted[["Jurisdiction", "Number of Deaths"]].groupby("Jurisdiction").sum("Number of Deaths")
num_deaths_by_state.reset_index(inplace=True)
print(f"Max:{num_deaths_by_state.max()}\n\nMin:{num_deaths_by_state.min()}")
# Out:
# Max:Jurisdiction          Wyoming
# Number of Deaths    1676102.0
# dtype: object
#
# Min:Jurisdiction        Alabama
# Number of Deaths     9386.0
# dtype: object
